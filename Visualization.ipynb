# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import pandas as pd

# %%
df = pd.read_csv('logs/training_log.csv')
df
# Out:
#     epoch      loss       acc
# 0       1  3.144018  0.179928
# 1       2  2.208409  0.373248
# 2       3  1.802378  0.472106
# 3       4  1.639498  0.517144
# 4       5  1.526617  0.540396
# ..    ...       ...       ...
# 95     96  0.233048  0.921278
# 96     97  0.228610  0.922697
# 97     98  0.225983  0.924123
# 98     99  0.222888  0.924944
# 99    100  0.224649  0.924533
#
# [100 rows x 3 columns]

# %%
sns.set()

# %%
plt.figure(figsize=(10, 8))
plt.plot(df['epoch'], df['loss'])
plt.title('Training Loss over Epochs')
plt.show()

# %%
plt.figure(figsize=(10, 8))
plt.plot(df['epoch'], df['acc'])
plt.title('Training Accuracy over Epochs')
plt.show()
